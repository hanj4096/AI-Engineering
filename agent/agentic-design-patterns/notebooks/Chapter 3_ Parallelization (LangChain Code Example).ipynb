# %% [markdown]
# # Chapter 3: Parallelization (代码示例)
#
# 本 notebook 演示了如何使用 LangChain 实现 Parallelization（并行化）模式。
#
# ## 前置要求
#
# - Python 3.8+
# - 阿里云 DashScope API Key（需要设置环境变量 `DASHSCOPE_API_KEY`）

# %% [markdown]
# ## 1. 安装依赖
#
# 首先安装所需的 Python 包。

# %%
# 安装必要的依赖包（使用 %pip 在 Jupyter 中更推荐）
# %pip install -q langchain-core>=0.1.0 langchain-community>=0.1.0 dashscope>=1.17.0 python-dotenv>=1.0.0 nest-asyncio
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. 获取 API Key
#
# 如果环境变量或 .env 文件中没有设置 `DASHSCOPE_API_KEY`，可以在此处直接设置。

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# 获取 API key（优先从环境变量读取，如果没有则从 .env 文件）
dashscope_api_key = os.getenv("DASHSCOPE_API_KEY")

# %% [markdown]
# ## 3. 导入库并初始化模型

# %%
import asyncio
import nest_asyncio
from typing import Optional

from langchain_community.chat_models import ChatTongyi
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import Runnable, RunnableParallel, RunnablePassthrough

# 允许在 Jupyter notebook 中运行异步代码
nest_asyncio.apply()

# --- Configuration ---
# 初始化 Qwen 语言模型（使用阿里云 DashScope API）
# model 参数可以指定不同的 Qwen 模型，如 "qwen-flash", "qwen-turbo", "qwen-plus", "qwen-max" 等
try:
    llm: Optional[ChatTongyi] = ChatTongyi(
        model="qwen-flash",
        temperature=0.7,
        dashscope_api_key=dashscope_api_key
    )
    if llm:
        print(f"Language model initialized: qwen-flash")
except Exception as e:
    print(f"Error initializing language model: {e}")
    llm = None


# --- Define Independent Chains ---
# These three chains represent distinct tasks that can be executed in parallel.

summarize_chain: Runnable = (
    ChatPromptTemplate.from_messages([
        ("system", "Summarize the following topic concisely:"),
        ("user", "{topic}")
    ])
    | llm
    | StrOutputParser()
)

questions_chain: Runnable = (
    ChatPromptTemplate.from_messages([
        ("system", "Generate three interesting questions about the following topic:"),
        ("user", "{topic}")
    ])
    | llm
    | StrOutputParser()
)

terms_chain: Runnable = (
    ChatPromptTemplate.from_messages([
        ("system", "Identify 5-10 key terms from the following topic, separated by commas:"),
        ("user", "{topic}")
    ])
    | llm
    | StrOutputParser()
)


# --- Build the Parallel + Synthesis Chain ---

# 1. Define the block of tasks to run in parallel. The results of these,
#    along with the original topic, will be fed into the next step.
map_chain = RunnableParallel(
    {
        "summary": summarize_chain,
        "questions": questions_chain,
        "key_terms": terms_chain,
        "topic": RunnablePassthrough(),  # Pass the original topic through
    }
)

# 2. Define the final synthesis prompt which will combine the parallel results.
synthesis_prompt = ChatPromptTemplate.from_messages([
    ("system", """Based on the following information:
     Summary: {summary}
     Related Questions: {questions}
     Key Terms: {key_terms}
     Synthesize a comprehensive answer."""),
    ("user", "Original topic: {topic}")
])

# 3. Construct the full chain by piping the parallel results directly
#    into the synthesis prompt, followed by the LLM and output parser.
full_parallel_chain = map_chain | synthesis_prompt | llm | StrOutputParser()


# --- Run the Chain ---
async def run_parallel_example(topic: str) -> None:
    """
    Asynchronously invokes the parallel processing chain with a specific topic
    and prints the synthesized result.

    Args:
        topic: The input topic to be processed by the LangChain chains.
    """
    if not llm:
        print("LLM not initialized. Cannot run example.")
        return

    print(f"\n--- Running Parallel LangChain Example for Topic: '{topic}' ---")
    try:
        # The input to `ainvoke` is the single 'topic' string, which is
        # then passed to each runnable in the `map_chain`.
        response = await full_parallel_chain.ainvoke(topic)
        print("\n--- Final Response ---")
        print(response)
    except Exception as e:
        print(f"\nAn error occurred during chain execution: {e}")

# 运行示例
# 在 Jupyter notebook 中，可以直接使用 await run_parallel_example(test_topic)
# 或者使用 asyncio.run()（需要 nest_asyncio 支持）
test_topic = "The history of space exploration"
asyncio.run(run_parallel_example(test_topic))
# Out:
# Language model initialized: qwen-flash
#
# --- Running Parallel LangChain Example for Topic: 'The history of space exploration' ---
# --- Final Response ---
# **The History of Space Exploration: From Theoretical Dreams to Global Collaboration**
#
# The history of space exploration is a remarkable journey spanning over a century, transforming humanity’s understanding of the cosmos and redefining our place in the universe. What began as speculative science fiction and theoretical physics evolved into one of the most ambitious technological and scientific endeavors in human history—driven by curiosity, national pride, Cold War competition, and ultimately, global cooperation.
#
# ### **Foundations of Rocketry and Early Visionaries (1920s–1940s)**
# Space exploration's roots lie in the pioneering work of visionary scientists who laid the theoretical groundwork for rocketry. Russian scientist **Konstantin Tsiolkovsky** formulated the foundational equations of rocket motion and envisioned space stations and interplanetary travel. In the United States, **Robert Goddard** conducted the first successful liquid-fueled rocket launch in 1926, proving that rockets could operate beyond Earth’s atmosphere. Meanwhile, German engineer **Wernher von Braun**, working under Nazi Germany’s military program, developed the V-2 rocket—a ballistic missile that became the precursor to modern space launch vehicles. Though born from wartime applications, these technologies would later become central to peaceful spaceflight.
#
# ### **The Dawn of the Space Age (1957–1961)**
# The launch of **Sputnik 1** by the Soviet Union on October 4, 1957, marked the true beginning of the **Space Age**. As the first artificial satellite to orbit Earth, Sputnik shocked the world and triggered the **space race** between the superpowers. This event not only demonstrated Soviet technological prowess but also spurred the United States to accelerate its own efforts. In response, NASA was established in 1958 to coordinate America’s civilian space program.
#
# The Soviet Union continued to lead in early milestones:
# - In 1961, **Yuri Gagarin** became the first human in space aboard **Vostok 1**, circling Earth in a single orbit.
# - The U.S. responded with Project Mercury, culminating in Alan Shepard’s suborbital flight and John Glenn’s orbital mission.
#
# ### **The Apollo Era and the Moon Landing (1969)**
# Driven by President John F. Kennedy’s 1961 challenge to land a man on the Moon before the end of the decade, the **Apollo program** emerged as the centerpiece of American ambition. After years of intense development, testing, and sacrifice—including the tragic loss of astronauts Gus Grissom, Ed White, and Roger Chaffee during a pre-launch test—the Apollo 11 mission achieved the ultimate milestone on July 20, 1969.
#
# **Neil Armstrong** and **Buzz Aldrin** became the first humans to walk on the lunar surface, while Michael Collins remained in orbit aboard the command module. Armstrong’s iconic words—“That’s one small step for man, one giant leap for mankind”—symbolized not just a technological triumph, but a moment of profound unity and hope for humanity.
#
# ### **Robotic Exploration and the Rise of Space Stations (1970s–1980s)**
# While crewed missions captured public imagination, robotic exploration expanded our knowledge of the solar system. NASA’s **Voyager 1 and 2** probes provided unprecedented images and data of Jupiter, Saturn, Uranus, and Neptune. The **Viking missions** landed on Mars in the 1970s, searching for signs of life. These missions revealed the dynamic nature of planetary systems and deepened our understanding of Earth’s place in the cosmos.
#
# In the 1980s, the U.S. introduced the **Space Shuttle program**, a reusable spacecraft designed to reduce costs and increase access to space. While it enabled critical missions like the deployment of the **Hubble Space Telescope** (launched in 1990), it also faced setbacks, including the Challenger disaster in 1986 and the Columbia tragedy in 2003—reminders of the risks inherent in human spaceflight.
#
# ### **Global Collaboration and the International Space Station (1990s–2000s)**
# The fall of the Berlin Wall and the end of the Cold War paved the way for international cooperation. The **Apollo-Soyuz Test Project** in 1975 symbolized the first joint U.S.-Soviet space mission, signaling a shift from rivalry to partnership. This spirit culminated in the construction of the **International Space Station (ISS)**, a multinational effort involving NASA (U.S.), Roscosmos (Russia), ESA (Europe), JAXA (Japan), and CSA (Canada).
#
# Launched in 1998 and continuously inhabited since 2000, the ISS has served as a floating laboratory for scientific research in microgravity, biology, physics, and Earth observation. It stands as a testament to what can be achieved when nations collaborate across political and cultural divides.
#
# ### **The New Era: Private Innovation and Deep-Space Ambitions (2010s–Present)**
# Since the 2010s, space exploration has entered a new phase defined by private enterprise and renewed ambition. Companies like **SpaceX**, founded by Elon Musk, have revolutionized the industry with reusable rockets (Falcon 9, Starship), dramatically lowering launch costs and enabling commercial crew missions to the ISS. Blue Origin, founded by Jeff Bezos, and other emerging players are also advancing space tourism and infrastructure.
#
# Robotic exploration continues to thrive:
# - The **Curiosity rover** (2012) and **Perseverance rover** (2021) have explored Mars, analyzing soil, searching for ancient microbial life, and even collecting samples for future return missions.
# - NASA’s **James Webb Space Telescope** (launched in 2021) has delivered stunning images of distant galaxies and early universe phenomena, pushing the boundaries of observational astronomy.
#
# Meanwhile, plans for returning humans to the Moon are underway through NASA’s **Artemis program**, aiming to land the first woman and next man on the lunar surface by the mid-2020s. The long-term vision includes establishing a sustainable lunar presence and eventually sending astronauts to **Mars**—a goal that unites scientific inquiry, technological innovation, and humanity’s enduring desire to explore.
#
# ---
#
# ### **Legacy and Future Outlook**
# From theoretical dreams to real-world achievements, the history of space exploration reflects humanity’s relentless curiosity and ingenuity. It has evolved from a tool of geopolitical rivalry into a shared endeavor for peace, discovery, and survival. The **key terms**—*rocketry*, *satellite*, *human spaceflight*, *Moon landing*, *Apollo program*, *NASA*, *International Space Station*, *Mars rover*, *space shuttle*, and *space exploration*—are more than buzzwords; they represent milestones in our collective journey beyond Earth.
#
# As we look forward, challenges remain: ensuring equitable access to space, managing space debris, sustaining long-duration human missions, and maintaining international collaboration amid geopolitical tensions. Yet the legacy of past achievements—Sputnik, the Moon landing, the ISS, and Perseverance—inspires a new generation to dream boldly.
#
# Ultimately, space exploration is not merely about reaching other worlds—it is about expanding the frontiers of human potential, understanding our origins, and securing a future where humanity may one day thrive among the stars.
